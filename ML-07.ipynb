# %%
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.
# Answer :-
# The Pearson correlation coefficient (often denoted as "r") is a measure of the linear relationship between two continuous variables. It quantifies the strength and direction of the linear association between the two variables. The Pearson correlation coefficient ranges from -1 to 1:

# If r = 1, it indicates a perfect positive linear relationship, meaning that as one variable increases, the other also increases in a perfectly linear manner.
# If r = -1, it indicates a perfect negative linear relationship, meaning that as one variable increases, the other decreases in a perfectly linear manner.
# If r = 0, it indicates no linear relationship between the variables. They are uncorrelated.
# To calculate the Pearson correlation coefficient between the amount of time students spend studying for an exam and their final exam scores, you can use the following formula:

# r= ​∑(Xi− Xˉ)(Yi − Yˉ)/∑(Xi − Xˉ)^2 ∑(Yi− Yˉ)^2
 
 
# Where:

# Xi and Yi are data points for the two variables (study time and exam scores).

# ˉXˉ and ˉYˉ are the means of the two variables.
# You need a dataset with pairs of values for study time and exam scores to perform this calculation. Once you have the dataset and calculate the Pearson correlation coefficient, you can interpret the result as follows:

# If r>0: There is a positive linear relationship between study time and exam scores. As students spend more time studying, their exam scores tend to be higher.

# If r<0: There is a negative linear relationship between study time and exam scores. As students spend more time studying, their exam scores tend to be lower.

# If r≈0: There is little to no linear relationship between study time and exam scores, meaning that the amount of time spent studying doesn't have a significant impact on exam scores in a linear manner.

# The magnitude of the correlation coefficient r indicates the strength of the relationship. The closer r is to -1 or 1, the stronger the linear relationship, while values closer to 0 indicate a weaker or no linear relationship.

# It's important to note that the Pearson correlation coefficient only measures linear relationships. Non-linear relationships may not be accurately captured by this metric. Additionally, correlation does not imply causation, so a strong correlation does not necessarily mean that studying causes higher exam scores. Other factors could be at play.

# %%
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.
# Answer :-
# Spearman's rank correlation, often denoted as "ρ" or "rs," is a non-parametric measure of the monotonic relationship between two variables. Unlike Pearson correlation, it does not assume that the relationship is necessarily linear. Instead, it assesses whether there is a consistent trend in the relationship, either increasing or decreasing.

# To calculate the Spearman's rank correlation between the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10, follow these steps:

# Rank the values for both variables separately. Assign a rank to each value, with 1 being the smallest value, 2 for the next smallest, and so on. If there are ties (i.e., repeated values), assign an average rank.

# Calculate the differences between the ranks for each pair of values. Square these differences.

# Calculate the Spearman's rank correlation using the following formula:


# ρ=1− 6∑d^2/n(n^2 −1)

# Where:


# d represents the differences between the ranks.

# n is the number of data points.
# Once you calculate ρ, you can interpret the result as follows:

# If ρ = 1, it indicates a perfect positive monotonic relationship. This means that as one variable increases, the other consistently increases, and as one variable decreases, the other consistently decreases.

# If ρ = -1, it indicates a perfect negative monotonic relationship. This means that as one variable increases, the other consistently decreases, and vice versa.

# If ρ = 0, it suggests no monotonic relationship between the variables. There is no consistent trend in the relationship.

# If -1 < ρ < 1, it indicates a moderate to strong monotonic relationship. The sign of ρ (positive or negative) indicates the direction of the relationship (increasing or decreasing), and the magnitude of ρ quantifies the strength of the relationship.

# In your specific case, if the calculated Spearman's rank correlation (ρ) is close to 1, it suggests a strong, positive monotonic relationship between the amount of sleep and job satisfaction. This would mean that individuals who get more sleep tend to report higher job satisfaction, and those who get less sleep tend to report lower job satisfaction.

# Conversely, if ρ is close to -1, it suggests a strong, negative monotonic relationship, indicating that individuals who get more sleep tend to report lower job satisfaction, and those who get less sleep tend to report higher job satisfaction.

# If ρ is close to 0, it suggests that there is no strong monotonic relationship between the two variables. The interpretation should take into account the magnitude of ρ and the specific context of the data and the study.

# %%
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.
# Answer :-
# To examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults, you can calculate both the Pearson correlation coefficient (r) and the Spearman's rank correlation (ρ) and then compare the results. Here's how you can do it:

# Step 1: Data Collection
# Collect the data on both variables (number of hours of exercise per week and BMI) for the 50 participants.

# Step 2: Calculate Pearson Correlation Coefficient (r)
# Pearson correlation measures linear relationships. Calculate it using the following formula:

# r= ​∑(Xi− Xˉ)(Yi − Yˉ)/∑(Xi − Xˉ)^2 ∑(Yi− Yˉ)^2

# Where:

# Xi and  Yi are data points for the two variables (exercise hours and BMI).
# ˉX and  ˉY are the means of the two variables.
# Step 3: Calculate Spearman's Rank Correlation (ρ)
# Spearman's rank correlation measures monotonic relationships. Calculate it using the following steps:

# Rank the values for both variables separately. Assign a rank to each value, with 1 being the smallest value, 2 for the next smallest, and so on. If there are ties (i.e., repeated values), assign an average rank.

# Calculate the differences between the ranks for each pair of values. Square these differences.

# Calculate ρ using the formula:

# ρ=1− 6∑d^2/n(n^2 −1)

# Where:

# d represents the differences between the ranks.
# n is the number of data points.
# Step 4: Interpret the Results

# If  r is close to 1, it suggests a strong, positive linear relationship between exercise hours and BMI, meaning that as the number of exercise hours increases, BMI tends to decrease (or vice versa).

# If  r is close to -1, it suggests a strong, negative linear relationship, indicating that as the number of exercise hours increases, BMI tends to increase (or vice versa).

# If  r is close to 0, it suggests no strong linear relationship between the two variables.

# If  ρ is close to 1, it suggests a strong, positive monotonic relationship between exercise hours and BMI, meaning that individuals who exercise more tend to have lower BMI values.

# If ρ is close to -1, it suggests a strong, negative monotonic relationship, indicating that individuals who exercise more tend to have higher BMI values.

# If  ρ is close to 0, it suggests no strong monotonic relationship between the two variables.

# Step 5: Compare the Results
# Compare the results of the Pearson correlation coefficient (r) and the Spearman's rank correlation (ρ). If both coefficients show similar trends (either positive or negative), it provides more confidence in the relationship. If they differ significantly, it might indicate a non-linear relationship between the variables.

# These calculations and comparisons will help you assess the nature and strength of the relationship between exercise hours and BMI in your sample of adults.

# %%
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.
# Answer :-


# To calculate the Pearson correlation coefficient (often denoted as "r") between the number of hours individuals spend watching television per day and their level of physical activity, you can use the following steps:

# Step 1: Data Collection
# Collect the data on both variables (daily hours of TV watching and level of physical activity) for the 50 participants.

# Step 2: Calculate Pearson Correlation Coefficient (r)
# Pearson correlation measures the linear relationship between two continuous variables. Calculate it using the following formula:

# r= ​∑(Xi− Xˉ)(Yi − Yˉ)/∑(Xi − Xˉ)^2 ∑(Yi− Yˉ)^2

# Where:

# Xi and Yi are data points for the two variables (TV hours and physical activity).

# ˉX and ˉYˉ are the means of the two variables.
# Step 3: Interpret the Result

# If r is close to 1, it indicates a strong, positive linear relationship between the number of hours individuals spend watching television and their level of physical activity. This would mean that as people watch more TV, their physical activity tends to increase.

# If r is close to -1, it suggests a strong, negative linear relationship, indicating that as individuals watch more TV, their level of physical activity tends to decrease.

# If r is close to 0, it suggests no strong linear relationship between the two variables, meaning that there may not be a significant linear correlation between TV-watching hours and physical activity levels.

# Interpreting the value of r will help you understand whether there is a linear association between the two variables in your dataset. It's important to keep in mind that correlation does not imply causation, and other factors may influence the relationship between TV-watching and physical activity.

# %%
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:

# Age(Years)
# 25 
# 42
# 37
# 19
# 31
# 28

# Soft Drink Preference 
# Coke
# Pepsi
# Mountain dew
# Coke
# Pepsi
# Coke

# Answer :-
# The provided survey data consists of two variables: "Age (Years)" and "Soft Drink Preference." The "Age (Years)" variable represents the ages of the respondents, while the "Soft Drink Preference" variable represents the brand of soft drink each respondent prefers.

# The survey results are as follows:

# Age (Years): 25, 42, 37, 19, 31, 28

# Soft Drink Preference: Coke, Pepsi, Mountain Dew, Coke, Pepsi, Coke

# To examine the relationship between age and soft drink preference, you can use different statistical methods, including summary statistics and visualization. However, calculating a correlation coefficient like Pearson's r or Spearman's ρ would not be applicable in this case because "Age (Years)" is a continuous variable, and "Soft Drink Preference" is a categorical variable with nominal categories (brands). Correlation measures are typically used for two continuous variables.

# To analyze the relationship between these two variables, you might consider the following approaches:

# Frequency Distribution: Create a frequency distribution to count how many respondents prefer each brand of soft drink within different age groups. This can help you understand if there is any age-related pattern in soft drink preferences.

# Bar Chart: Create a bar chart or bar plot to visualize the distribution of soft drink preferences within different age groups. This visual representation can provide insights into the most preferred brand in each age group.

# Summary Statistics: Calculate summary statistics, such as the mean or median age for each brand preference. This can provide an overview of the central tendency of age within each brand group.

# Without additional data and a clear research question, it may be challenging to derive specific conclusions about the relationship between age and soft drink preference. However, the approaches mentioned above can help you explore and summarize the data for initial insights.
