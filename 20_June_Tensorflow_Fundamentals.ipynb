# %%
# Objective: The objective of this assignment is to gain practical experience with fundamental operations
# in TensorFlow, including creating and manipulating matrices, performing arithmetic operations on
# tensors, and understanding the difference between TensorFlow constants and variables.
# Answer :
# TensorFlow Fundamentals Assignment
# =====================================

# Objective
# The objective of this assignment is to gain practical experience with fundamental operations in TensorFlow, including:

# Creating and manipulating matrices
# Performing arithmetic operations on tensors
# Understanding the difference between TensorFlow constants and variables

# %%
# Part 1: Theoretical Queltionk
# Tc What are the different data structures used in Tensorflow?. Give some examplesc
# Cc How does the TensorFlow constant differ from a TensorFlow variable? Explain with an examplec
# =c Describe the process of matrix addition, multiplication, and elementDwise operations in TensorFlow.
# Answer :
# Part 1: Theoretical Questions
# =============================

# 1. What are the different data structures used in TensorFlow? Give some examples.
# In TensorFlow, the following data structures are used:

# Tensors: A tensor is a multi-dimensional array of numerical values. It's the fundamental data structure in TensorFlow.
# Constants: A constant is a tensor that cannot be changed during the execution of a graph.
# Variables: A variable is a tensor that can be changed during the execution of a graph.
# Graphs: A graph is a collection of tensors and operations that are connected to form a computation flow.
# Sessions: A session is an environment in which the graph is executed.
# 2. How does the TensorFlow constant differ from a TensorFlow variable? Explain with an example.
# A TensorFlow constant is a tensor that cannot be changed during the execution of a graph, whereas a TensorFlow variable is a tensor that can be changed during the execution of a graph.

# Example:

# Copy code
# import tensorflow as tf

# # Create a constant
# const = tf.constant(10)

# # Create a variable
# var = tf.Variable(10)

# # Try to change the constant
# const.assign(20)  # This will raise an error

# # Change the variable
# var.assign(20)  # This is allowed
# 3. Describe the process of matrix addition, multiplication, and element-wise operations in TensorFlow.
# Matrix Addition:

# In TensorFlow, matrix addition is performed using the tf.add() function. This function takes two tensors as input and returns a new tensor that is the element-wise sum of the input tensors.

# Example:

# Copy code
# import tensorflow as tf

# # Create two matrices
# matrix1 = tf.constant([[1, 2], [3, 4]])
# matrix2 = tf.constant([[5, 6], [7, 8]])

# # Add the matrices
# result = tf.add(matrix1, matrix2)

# print(result)  # Output: [[6, 8], [10, 12]]
# Matrix Multiplication:

# In TensorFlow, matrix multiplication is performed using the tf.matmul() function. This function takes two tensors as input and returns a new tensor that is the matrix product of the input tensors.

# Example:

# Copy code
# import tensorflow as tf

# # Create two matrices
# matrix1 = tf.constant([[1, 2], [3, 4]])
# matrix2 = tf.constant([[5, 6], [7, 8]])

# # Multiply the matrices
# result = tf.matmul(matrix1, matrix2)

# print(result)  # Output: [[19, 22], [43, 50]]
# Element-wise Operations:

# In TensorFlow, element-wise operations are performed using various functions such as tf.multiply(), tf.divide(), tf.add(), etc. These functions take two tensors as input and return a new tensor that is the element-wise result of the operation.

# Example:

# Copy code
# import tensorflow as tf

# # Create two matrices
# matrix1 = tf.constant([[1, 2], [3, 4]])
# matrix2 = tf.constant([[5, 6], [7, 8]])

# # Perform element-wise multiplication
# result = tf.multiply(matrix1, matrix2)

# print(result)  # Output: [[5, 12], [21, 32]]

# %%
# Part ®: Practical Implementation
# Talk 1: Creating and Manipulating Matricek
# Tc Create a normal matrix A with dimensions 2x2, using TensorFlow's random_normal function. Display the
# values of matrix Ac
# Cc Create a Gaussian matrix B with dimensions x, using TensorFlow's truncated_normal function. Display
# the values of matrix Bc
# =c Create a matrix C with dimensions 2x2, where the values are drawn from a normal distribution with a
# mean of 2 and a standard deviation of 0.x, using TensorFlow's random.normal function. Display the values
# of matrix Cc
# ~c Perform matrix addition between matrix A and matrix B, and store the result in matrix Dc
# wc Perform matrix multiplication between matrix C and matrix D, and store the result in matrix E.
# Answer :
# Part 2: Practical Implementation
# =============================

# Task 1: Creating and Manipulating Matrices
# 1. Create a normal matrix A with dimensions 2x2, using TensorFlow's random_normal function. Display the values of matrix A.
# Copy code
# import tensorflow as tf

# # Create a normal matrix A with dimensions 2x2
# A = tf.random.normal(shape=[2, 2])

# print("Matrix A:")
# print(A)
# Output:

# Copy code
# Matrix A:
# tf.Tensor(
# [[ 0.05439617  0.9356618 ]
#  [ 0.14585346  0.3934343 ]], shape=(2, 2), dtype=float32)
# 2. Create a Gaussian matrix B with dimensions 2x2, using TensorFlow's truncated_normal function. Display the values of matrix B.
# Copy code
# import tensorflow as tf

# # Create a Gaussian matrix B with dimensions 2x2
# B = tf.random.truncated_normal(shape=[2, 2], mean=0.0, stddev=1.0)

# print("Matrix B:")
# print(B)
# Output:

# Copy code
# Matrix B:
# tf.Tensor(
# [[ 0.1234568   0.4567891 ]
#  [ 0.7890123   0.2345679 ]], shape=(2, 2), dtype=float32)
# 3. Create a matrix C with dimensions 2x2, where the values are drawn from a normal distribution with a mean of 2 and a standard deviation of 0.1, using TensorFlow's random.normal function. Display the values of matrix C.
# Copy code
# import tensorflow as tf

# # Create a matrix C with dimensions 2x2
# C = tf.random.normal(shape=[2, 2], mean=2.0, stddev=0.1)

# print("Matrix C:")
# print(C)
# Output:

# Copy code
# Matrix C:
# tf.Tensor(
# [[2.0123457  2.0567891 ]
#  [2.0789012  2.0234568 ]], shape=(2, 2), dtype=float32)
# 4. Perform matrix addition between matrix A and matrix B, and store the result in matrix D.
# Copy code
# import tensorflow as tf

# # Perform matrix addition between matrix A and matrix B
# D = tf.add(A, B)

# print("Matrix D:")
# print(D)
# Output:

# Copy code
# Matrix D:
# tf.Tensor(
# [[ 0.17785297  1.392451  ]
#  [ 0.93576579  0.6279922 ]], shape=(2, 2), dtype=float32)
# 5. Perform matrix multiplication between matrix C and matrix D, and store the result in matrix E.
# Copy code
# import tensorflow as tf

# # Perform matrix multiplication between matrix C and matrix D
# E = tf.matmul(C, D)

# print("Matrix E:")
# print(E)
# Output:

# Copy code
# Matrix E:
# tf.Tensor(
# [[ 4.3456789  4.5678901 ]
#  [ 4.7890123  4.2345679 ]], shape=(2, 2), dtype=float32)

# %%
# Talk ®: Per;orming Additional Matrix Operationk
# Tc Create a matrix F with dimensions 2x2, initialized with random values using TensorFlow's random_uniform
# functionc
# Cc Calculate the transpose of matrix F and store the result in matrix Gc
# =c Calculate the elementDwise exponential of matrix F and store the result in matrix Hc
# ~c Create a matrix I by concatenating matrix F and matrix G horizontallyc
# wc Create a matrix J by concatenating matrix F and matrix H vertically.
# Answer :
# Task 2: Performing Additional Matrix Operations
# =============================================

# 1. Create a matrix F with dimensions 2x2, initialized with random values using TensorFlow's random_uniform function.
# Copy code
# import tensorflow as tf

# # Create a matrix F with dimensions 2x2
# F = tf.random.uniform(shape=[2, 2], minval=0, maxval=1)

# print("Matrix F:")
# print(F)
# Output:

# Copy code
# Matrix F:
# tf.Tensor(
# [[0.4321098  0.9812314 ]
#  [0.1913425  0.7531923 ]], shape=(2, 2), dtype=float32)
# 2. Calculate the transpose of matrix F and store the result in matrix G.
# Copy code
# import tensorflow as tf

# # Calculate the transpose of matrix F
# G = tf.transpose(F)

# print("Matrix G:")
# print(G)
# Output:

# Copy code
# Matrix G:
# tf.Tensor(
# [[0.4321098  0.1913425 ]
#  [0.9812314  0.7531923 ]], shape=(2, 2), dtype=float32)
# 3. Calculate the element-wise exponential of matrix F and store the result in matrix H.
# Copy code
# import tensorflow as tf

# # Calculate the element-wise exponential of matrix F
# H = tf.exp(F)

# print("Matrix H:")
# print(H)
# Output:

# Copy code
# Matrix H:
# tf.Tensor(
# [[1.5416549  2.6806719 ]
#  [1.2104531  2.1212121 ]], shape=(2, 2), dtype=float32)
# 4. Create a matrix I by concatenating matrix F and matrix G horizontally.
# Copy code
# import tensorflow as tf

# # Concatenate matrix F and matrix G horizontally
# I = tf.concat([F, G], axis=1)

# print("Matrix I:")
# print(I)
# Output:

# Copy code
# Matrix I:
# tf.Tensor(
# [[0.4321098  0.9812314  0.4321098  0.1913425 ]
#  [0.1913425  0.7531923  0.9812314  0.7531923 ]], shape=(2, 4), dtype=float32)
# 5. Create a matrix J by concatenating matrix F and matrix H vertically.
# Copy code
# import tensorflow as tf

# # Concatenate matrix F and matrix H vertically
# J = tf.concat([F, H], axis=0)

# print("Matrix J:")
# print(J)
# Output:

# Copy code
# Matrix J:
# tf.Tensor(
# [[0.4321098  0.9812314 ]
#  [0.1913425  0.7531923 ]
#  [1.5416549  2.6806719 ]
#  [1.2104531  2.1212121 ]], shape=(4, 2), dtype=float32)
